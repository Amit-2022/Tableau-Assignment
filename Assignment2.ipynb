# %% [markdown]
# Quiz
# Create following summary table
# 
# Use Superstore_Canada.xls and format your numbers exactly like
# shown in screenshot below
# Quiz
# Quiz ––Create following summary tableCreate following summary table
# 
# Use Use ––Superstore_Canada.xls and format your numbers exactly like Superstore_Canada.xls and format your numbers exactly like shown in screenshot belowshown in screenshot below
# Quiz
# Quiz
# 
# Import Import ––Superstore_Canada.xls (Sheet Superstore_Canada.xls (Sheet ––Orders) and answer the Orders) and answer the following questions:following questions:
# A.
# A.What is the total sales of the store? What is the total sales of the store?
# B.
# B.What is the total sales of product category = “Furniture”? What is the total sales of product category = “Furniture”?
# C.
# C.What is the total sales of product category = “Furniture” sold to Customer What is the total sales of product category = “Furniture” sold to Customer Segment = “Corporate”? Segment = “Corporate”?
# D.
# D.Set the default number format of Discount to percentage with 2 decimal Set the default number format of Discount to percentage with 2 decimal places.places.
# E.
# E.Find average discount on each order priority. Which order priority has Find average discount on each order priority. Which order priority has highest average discount? highest average discount?
# Quiz Answer
# Quiz Answer
# 
# Import Import ––Superstore_Canada.xls (Sheet Superstore_Canada.xls (Sheet ––Orders) and answer the Orders) and answer the following questions:following questions:
# A.
# A.What is the total sales of the store? (What is the total sales of the store? (AnsAns––14,915,601)14,915,601)
# B.
# B.What is the total sales of product category = “Furniture”? (What is the total sales of product category = “Furniture”? (AnsAns––5,178,591)5,178,591)
# C.
# C.What is the total sales of product category = “Furniture” sold to Customer What is the total sales of product category = “Furniture” sold to Customer Segment = “Corporate”? (Segment = “Corporate”? (AnsAns––1,862,841)1,862,841)
# D.
# D.Set the number format of Discount to percentage with 2 decimal places.Set the number format of Discount to percentage with 2 decimal places.
# E.
# E.What order priority has highest average discount? (What order priority has highest average discount? (AnsAns––Low at 5.04%)Low at 5.04%)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

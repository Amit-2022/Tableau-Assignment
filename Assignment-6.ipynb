# %% [markdown]
# Find the inventory by:- • Category • Sub Category • Product • Location - Create a Dashboard - Create a story showing the visuals from Location, Product & Category

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
